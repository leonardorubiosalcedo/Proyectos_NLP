# %% [markdown]
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ-VfNtOyJbsaxu43Kztf_cv1mgBG6ZIQZEVw&usqp=CAU'>
#
# # Procesamiento de Lenguage Natural
#
# ## Taller #10: Modelado de temas
# `Fecha de entrega: 🎃Noviembre 07, 2020. (Antes del inicio de la próxima clase).`
#
# `Modo de entrega: Subir link de GitHub al aula virtual.`
#
# Leonardo Rubio Salcedo

# %% [markdown]
# En el siguiente proyecto se intentara determinar por descripcion de las peliculas si cuentan con estereotipos y donde se presentan mas repeticiones

# %%
import pandas as pd

import numpy as np
 
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
 
from nltk.corpus import stopwords
stopwords = stopwords.words('english')
 
import matplotlib.pyplot as plt
import PIL.Image
from IPython.display import display

# %%
datos = pd.read_excel("salida_scraping.xlsx")
datos.head()
# Out:
#       budget                        company country          director  \
# 0  100000000           Red Granite Pictures     USA   Martin Scorsese
# 1   20000000                New Line Cinema     USA         James Wan
# 2   46000000            Alcon Entertainment     USA  Denis Villeneuve
# 3  150000000  Walt Disney Animation Studios     USA        Chris Buck
# 4   75000000           Summit Entertainment     USA   Louis Leterrier
#
#        genre      gross                     name rating  day_released  \
# 0  Biography  116900694  The Wolf of Wall Street      R            25
# 1     Horror  137400141            The Conjuring      R            19
# 2      Crime   61002302                Prisoners      R            20
# 3  Animation  400738009                   Frozen     PG            27
# 4      Crime  117723989           Now You See Me  PG-13            31
#
#    month_released  ...  year               hashtag               name_roten  \
# 0              12  ...  2013  #TheWolfofWallStreet  the_wolf_of_wall_street
# 1               7  ...  2013         #TheConjuring            the_conjuring
# 2               9  ...  2013            #Prisoners                prisoners
# 3              11  ...  2013               #Frozen                   frozen
# 4               5  ...  2013          #NowYouSeeMe           now_you_see_me
#
#    calificacion1 calificacion2  \
# 0            87%           80%
# 1            87%           86%
# 2            87%           81%
# 3            87%           56%
# 4            87%           51%
#
#                                             synopsis  \
# 0  in 1987  jordan belfort  leonardo dicaprio  ta...
# 1  in 1970  paranormal investigators and demonolo...
# 2  keller dover  hugh jackman  faces a parent s w...
# 3  a performance artist turns his suicide into a ...
# 4  charismatic magician atlas  jesse eisenberg  l...
#
#                                                 ruta  sabado_estreno  \
# 0  https://www.rottentomatoes.com/m/the_wolf_of_w...      2013-12-28
# 1     https://www.rottentomatoes.com/m/the_conjuring      2013-07-20
# 2    https://www.rottentomatoes.com/m/prisoners_2013      2013-09-21
# 3            https://www.rottentomatoes.com/m/frozen      2013-11-30
# 4    https://www.rottentomatoes.com/m/now_you_see_me      2013-06-01
#
#   domingo_estrono mes_siguiente
# 0      2013-12-29    2014-01-24
# 1      2013-07-21    2013-08-18
# 2      2013-09-22    2013-10-20
# 3      2013-12-01    2013-12-27
# 4      2013-06-02    2013-06-30
#
# [5 rows x 27 columns]

# %%
agrupaciones=datos['genre'].unique()
agrupaciones
# Out:
# array(['Biography', 'Horror', 'Crime', 'Animation', 'Drama', 'Action',
#        'Comedy', 'Adventure', 'Fantasy', 'Mystery', 'Sci-Fi', 'Romance',
#        'Thriller', 'Western'], dtype=object)

# %%
def generar_grafico(datos,imagen):
    calabaza = PIL.Image.open(imagen)
    mask = np.array(calabaza)
    palabras = datos.synopsis.str.cat(sep=' ')
    wordcloud = WordCloud(width=800, height=400,
                         max_font_size=150, max_words=800,
                         background_color='black', 
                         colormap='copper_r',
                         stopwords=stopwords,
                         mask=mask, contour_width=0.5, contour_color='white').generate(palabras) # https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html
                         #title= "Ejemplo"
    wordcloud.to_file(imagen)

    plt.figure(figsize=(10,8))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.tight_layout(pad=0)
    plt.title="Ejemplo"
    return plt

# %% [markdown]
# # Peliculas
# graficos por clasificacion de peliculas

# %%
Biography=datos[datos['genre']=="Biography"]
generar_grafico(Biography,"Biography.png")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
Biography=datos[datos['genre']=="Thriller"]
generar_grafico(Biography,"Thriller.png")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
Biography=datos[datos['genre']=="Horror"]
generar_grafico(Biography,"Horror.png")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
Biography=datos[datos['genre']=="Crime"]
generar_grafico(Biography,"Crime.png")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
Biography=datos[datos['genre']=="Animation"]
generar_grafico(Biography,"Animation.png")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
Biography=datos[datos['genre']=="Drama"]
generar_grafico(Biography,"Drama.png")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
Biography=datos[datos['genre']=="Action"]
generar_grafico(Biography,"Action.png")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
Biography=datos[datos['genre']=="Comedy"]
generar_grafico(Biography,"Comedy.png")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
Biography=datos[datos['genre']=="Adventure"]
generar_grafico(Biography,"Adventure.png")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
Biography=datos[datos['genre']=="Fantasy"]
generar_grafico(Biography,"Fantasy.png")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
Biography=datos[datos['genre']=="Mystery"]
generar_grafico(Biography,"Mystery.png")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
Biography=datos[datos['genre']=="Sci-Fi"]
generar_grafico(Biography,"Sci-Fi.png")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
Biography=datos[datos['genre']=="Romance"]
generar_grafico(Biography,"Romance.png")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
Biography=datos[datos['genre']=="Western"]
generar_grafico(Biography,"Western.png")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>
